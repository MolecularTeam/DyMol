# %% [markdown]
# ## Paper title: Dynamic Many-Objective Molecular Optimization: Unfolding Complexity with Objective Decomposition and Progressive Optimization
# ### Example code for QED + SA + JNK3 + GSK3bThis code works at colab (2024.5.17)

# %% [markdown]
# ### Install codes and dependencies

# %%
# !FILE_ID=1RJlptGiVvdu5cAf5ZfT7DPdodl6CJdeh && FILE_NAME=DyMol.zip && wget --no-check-certificate --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILE_ID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=$FILE_ID" -O $FILE_NAME && rm -rf /tmp/cookies.txt
# !mkdir DyMol && unzip DyMol.zip -d DyMol/
# !pip install numpy==1.26 rdkit pymoo pygmo PyTDC reinvent-chemistry==0.0.50 reinvent-models==0.0.15rc1 reinvent-scoring==0.0.73 wandb botorch dacite
# Out:
# --2024-01-16 07:57:27--  https://docs.google.com/uc?export=download&confirm=&id=1Q4fWhvnjeaNH3J43N0Fx2CY6bP_8Vj9P
# Resolving docs.google.com (docs.google.com)... 108.177.111.139, 108.177.111.113, 108.177.111.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.111.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1Q4fWhvnjeaNH3J43N0Fx2CY6bP_8Vj9P&export=download [following]
# --2024-01-16 07:57:27--  https://drive.usercontent.google.com/download?id=1Q4fWhvnjeaNH3J43N0Fx2CY6bP_8Vj9P&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.161.132, 2607:f8b0:4001:c5c::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.161.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22450489 (21M) [application/octet-stream]
# Saving to: ‘DyMol.zip’
#
# ...

# %% [markdown]
# ### Just run the code

# %%
# !cd /content/DyMol && python run.py reinvent_cl --oracles qed:1+sa:1+jnk3:1+gsk3b:1 --seed=1
# Out:
# reinvent_cl
# Optimizing oracle function: qed:1+sa:1+jnk3:1+gsk3b:1
# ...
# 100% 10.9M/10.9M [00:00<00:00, 32.6MiB/s]
# Done!
# ...
# 100% 27.8M/27.8M [00:01<00:00, 19.1MiB/s]
# Done!
# Downloading...
# 100% 11.8M/11.8M [00:00<00:00, 34.9MiB/s]
# Loading...
# Done!
# ...
#   Cloning https://github.com/PatWalters/rd_filters.git to /tmp/pip-req-build-vbut0k9f
#   Running command git clone --filter=blob:none --quiet https://github.com/PatWalters/rd_filters.git /tmp/pip-req-build-vbut0k9f
#   Resolved https://github.com/PatWalters/rd_filters.git to commit 3630f1a59150b4a203c2f06d8376a66d1d4c3f70
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rd-filters: filename=rd_filters-0.1-py3-none-any.whl size=33864 sha256=aac4c446197af2f7a7605ea02ba99c653b892cf34cc7f397dfff483b0aff6d92
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g586rv35/wheels/1d/57/d3/243da16d0396df21d623d6c41bcae207900be0f3f1a4e3224f
# ...
